# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import arviz as az
import torch
import pyro
from pyro import distributions as dist
from pyro.infer import MCMC, NUTS, Predictive
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn.preprocessing import LabelEncoder
import re
import calendar
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

#%matplotlib inline


# Поменять на свой ник на lichess
player = 'Oliverw-w'
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Код для парсинга pgn файла:
#
#
# ```python
# import chess.pgn
# import csv
# with open('data_oliver.pgn', encoding='utf-8') as pgn_file:
#     game = chess.pgn.read_game(pgn_file)
#     with open('data_oliver.csv', 'w', newline='', encoding='utf-8') as csv_file:
#         csv_writer = csv.writer(csv_file)
#
#         # Запись заголовков CSV файла
#         csv_writer.writerow(['Event', 'Site', 'Date', 'UTCTime', 'White', 'Black', 'WhiteElo', 'BlackElo', 'Result'])
#
#         while game is not None:
#             headers = game.headers
#             result = headers.get('Result', 'N/A')
#             csv_writer.writerow([
#                 headers.get('Event', 'N/A'),
#                 headers.get('Site', 'N/A'),
#                 headers.get('Date', 'N/A'),
#                 headers.get('UTCTime', 'N/A'),
#                 headers.get('White', 'N/A'),
#                 headers.get('Black', 'N/A'),
#                 headers.get('WhiteElo', 'N/A'),
#                 headers.get('BlackElo', 'N/A'),
#                 result
#             ])
#             game = chess.pgn.read_game(pgn_file)
# ```

# %%
df = pd.read_csv('data_oliver.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8813 entries, 0 to 8812
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Event     8813 non-null   object
#  1   Site      8813 non-null   object
#  2   Date      8813 non-null   object
#  3   UTCTime   8813 non-null   object
#  4   White     8813 non-null   object
#  5   Black     8813 non-null   object
#  6   WhiteElo  8813 non-null   object
#  7   BlackElo  8813 non-null   object
#  8   Result    8813 non-null   object
# dtypes: object(9)
# memory usage: 619.8+ KB

# %%
df.isnull().sum()
# Out:
# Event       0
# Site        0
# Date        0
# UTCTime     0
# White       0
# Black       0
# WhiteElo    0
# BlackElo    0
# Result      0
# dtype: int64

# %%
df
# Out:
#                            Event                          Site        Date  \
# 0               Rated Blitz game  https://lichess.org/5vO8FHzM  2024.03.11
# 1               Rated Blitz game  https://lichess.org/TVNFddJ3  2024.03.11
# 2               Rated Blitz game  https://lichess.org/UXNrd6CZ  2024.03.11
# 3               Rated Blitz game  https://lichess.org/QsoSb7Wx  2024.03.11
# 4               Rated Blitz game  https://lichess.org/k6MxHcs9  2024.03.11
# ...                          ...                           ...         ...
# 8808  Casual Correspondence game  https://lichess.org/NLdqUrXL  2021.01.04
# 8809  Casual Correspondence game  https://lichess.org/y0H7lT7U  2021.01.04
# 8810            Rated Rapid game  https://lichess.org/8N1V9o10  2021.01.02
# 8811            Rated Rapid game  https://lichess.org/e9ar4gaG  2021.01.02
# 8812  Casual Correspondence game  https://lichess.org/3Uy3kenV  2021.01.02
#
#        UTCTime               White               Black WhiteElo BlackElo  \
# 0     17:57:31           Oliverw-w          MaybePirog     1806     1787
# 1     17:02:39           Nkugwache           Oliverw-w     1831     1811
# 2     15:46:11           Oliverw-w        drewcaldinho     1807     1708
# 3     15:42:01            sanzh_33           Oliverw-w     1759     1802
# 4     12:38:16           Oliverw-w     helton_santiago     1796     1792
# ...        ...                 ...                 ...      ...      ...
# 8808  21:16:09  lichess AI level 4           Oliverw-w        ?     1500
# 8809  21:05:46           Oliverw-w  lichess AI level 4     1500        ?
# 8810  15:47:34          Karuso4711           Oliverw-w     1329     1320
# 8811  15:45:35           Oliverw-w    YellowCurryNinja     1500     1602
# 8812  15:32:02           Oliverw-w  lichess AI level 1     1500        ?
#
#      Result
# 0       1-0
# 1       1-0
# 2       1-0
# 3       0-1
# 4       1-0
# ...     ...
# 8808    1-0
# 8809    0-1
# 8810    1-0
# 8811    0-1
# 8812    1-0
#
# [8813 rows x 9 columns]

# %%
def determine_tournament_type(x):
    if re.search(r'\bRated\b', x):  # 'Rated' как отдельное слово
        return '0'
    return '1'

df['Tournament'] = df['Event'].apply(determine_tournament_type)

# %%
df['chess_clock'] = df['Event'].str.extract(r'(\b(?:Bullet|Blitz|Ultrabullet|Rapid)\b)', flags=re.IGNORECASE, expand=False)
df['chess_clock'] = df['chess_clock'].fillna('other')
df['chess_clock'] = df['chess_clock'].replace('BULLET', 'other')

# %%
def determine_time_of_day(time):
    hour = int(time.split(':')[0])
    if 0 <= hour < 6:
        return 'night'
    elif 6 <= hour < 12:
        return 'morning'
    elif 12 <= hour < 18:
        return 'afternoon'
    else:
        return 'evening'

df['time_day'] = df['UTCTime'].apply(determine_time_of_day)

# %%
def determine_result(row):
    if player in row['White']:
        return row['Result'].split('-')[0]
    elif player in row['Black']:
        return row['Result'].split('-')[1]
    else:
        return None
    
def determine_result_opponent(row):
    if player in row['White']:
        return row['Result'].split('-')[1]
    elif player in row['Black']:
        return row['Result'].split('-')[0]
    else:
        return None
df['result_player'] = df.apply(determine_result, axis=1)
df['result_opponent'] = df.apply(determine_result_opponent, axis=1)

# %%
df['player_elo'] = ''
df['opponent_elo'] = ''

df.loc[df['White'] == player, 'player_elo'] = df['WhiteElo']
df.loc[df['Black'] == player, 'player_elo'] = df['BlackElo']

df.loc[df['White'] != player, 'opponent_elo'] = df['WhiteElo']
df.loc[df['Black'] != player, 'opponent_elo'] = df['BlackElo']


df = df[df['opponent_elo'] != '?']

# %%
df['month_game'] = pd.to_datetime(df['Date']).dt.month
df['year_game'] = pd.to_datetime(df['Date']).dt.year

df['month_game'] = df['month_game'].apply(lambda x: calendar.month_name[x])
df['year_game'] = df['year_game'].apply(lambda x: str(x))
# Out:
# C:\Users\walta\AppData\Local\Temp\ipykernel_18948\1883393780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month_game'] = pd.to_datetime(df['Date']).dt.month
# C:\Users\walta\AppData\Local\Temp\ipykernel_18948\1883393780.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_game'] = pd.to_datetime(df['Date']).dt.year
# C:\Users\walta\AppData\Local\Temp\ipykernel_18948\1883393780.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month_game'] = df['month_game'].apply(lambda x: calendar.month_name[x])
# C:\Users\walta\AppData\Local\Temp\ipykernel_18948\1883393780.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year_game'] = df['year_game'].apply(lambda x: str(x))

# %%
for col in ["Event", "White","Black", "Result", "Tournament", 'chess_clock', 'time_day', 'result_player']:
    print(df[col].value_counts(), end="\n\n")
# Out:
# Event
# Rated Blitz game              6230
# Rated Bullet game             1251
# Rated Rapid game               180
# Casual Correspondence game     132
# Casual Blitz game              119
#                               ...
# Monthly Blitz Arena              2
# Отборочный этап АССК             2
# Чемпионат АССК ВолгГМУ           2
# ≤2000 Bullet Arena               1
# Импульс здоровья                 1
# Name: count, Length: 61, dtype: int64
#
# White
# Oliverw-w          4362
# Chizho_A1exandr      80
# Okiamback            65
# Emchenov_Dorgi       25
# waltalgg             18
#                    ...
# MA9                   1
# LIS_Leo               1
# teshxy                1
# hidalgocordones       1
# Karuso4711            1
# Name: count, Length: 4019, dtype: int64
#
# Black
# Oliverw-w           4365
# Chizho_A1exandr       84
# Okiamback             62
# Sofochkkka            29
# Emchenov_Dorgi        25
#                     ...
# SaveTheQueen2020       1
# DoctorChu              1
# Querspringer           1
# Braklav                1
# YellowCurryNinja       1
# Name: count, Length: 4027, dtype: int64
#
# Result
# 1-0        4422
# 0-1        3973
# 1/2-1/2     332
# Name: count, dtype: int64
#
# Tournament
# 0    7736
# 1     991
# Name: count, dtype: int64
#
# chess_clock
# Blitz          6503
# Bullet         1372
# other           578
# Rapid           253
# UltraBullet      21
# Name: count, dtype: int64
#
# time_day
# afternoon    3460
# evening      2814
# morning      2203
# night         250
# Name: count, dtype: int64
#
# result_player
# 1      4359
# 0      4036
# 1/2     332
# Name: count, dtype: int64

# %%
def pie(df, columns):
    for column in columns:
        value_counts = df[column].value_counts()    
        plt.figure(figsize=(8, 8))
        plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
        plt.title(f'Pie for column "{column}"')
        plt.show()
        
category_columns = ["Result", "Tournament", 'chess_clock', 'time_day', 'result_player', 'month_game', 'year_game']
pie(df, category_columns)

# %%
df
# Out:
#                            Event                          Site        Date  \
# 0               Rated Blitz game  https://lichess.org/5vO8FHzM  2024.03.11
# 1               Rated Blitz game  https://lichess.org/TVNFddJ3  2024.03.11
# 2               Rated Blitz game  https://lichess.org/UXNrd6CZ  2024.03.11
# 3               Rated Blitz game  https://lichess.org/QsoSb7Wx  2024.03.11
# 4               Rated Blitz game  https://lichess.org/k6MxHcs9  2024.03.11
# ...                          ...                           ...         ...
# 8765            Rated Rapid game  https://lichess.org/beR9NqVQ  2021.03.14
# 8767  Casual Correspondence game  https://lichess.org/0hIzN9KM  2021.03.12
# 8768  Casual Correspondence game  https://lichess.org/nR0hvNQj  2021.03.12
# 8810            Rated Rapid game  https://lichess.org/8N1V9o10  2021.01.02
# 8811            Rated Rapid game  https://lichess.org/e9ar4gaG  2021.01.02
#
#        UTCTime       White             Black WhiteElo BlackElo Result  \
# 0     17:57:31   Oliverw-w        MaybePirog     1806     1787    1-0
# 1     17:02:39   Nkugwache         Oliverw-w     1831     1811    1-0
# 2     15:46:11   Oliverw-w      drewcaldinho     1807     1708    1-0
# 3     15:42:01    sanzh_33         Oliverw-w     1759     1802    0-1
# 4     12:38:16   Oliverw-w   helton_santiago     1796     1792    1-0
# ...        ...         ...               ...      ...      ...    ...
# 8765  08:38:32    lolliray         Oliverw-w     1155     1177    0-1
# 8767  19:52:00   Oliverw-w          waltalgg     1500     1500    1-0
# 8768  19:25:11   Oliverw-w          waltalgg     1500     1500    0-1
# 8810  15:47:34  Karuso4711         Oliverw-w     1329     1320    1-0
# 8811  15:45:35   Oliverw-w  YellowCurryNinja     1500     1602    0-1
#
#      Tournament chess_clock   time_day result_player result_opponent  \
# 0             0       Blitz  afternoon             1               0
# 1             0       Blitz  afternoon             0               1
# 2             0       Blitz  afternoon             1               0
# 3             0       Blitz  afternoon             1               0
# 4             0       Blitz  afternoon             1               0
# ...         ...         ...        ...           ...             ...
# 8765          0       Rapid    morning             1               0
# 8767          1       other    evening             1               0
# 8768          1       other    evening             0               1
# 8810          0       Rapid  afternoon             0               1
# 8811          0       Rapid  afternoon             0               1
#
#      player_elo opponent_elo month_game year_game
# 0          1806         1787      March      2024
# 1          1811         1831      March      2024
# 2          1807         1708      March      2024
# 3          1802         1759      March      2024
# 4          1796         1792      March      2024
# ...         ...          ...        ...       ...
# 8765       1177         1155      March      2021
# 8767       1500         1500      March      2021
# 8768       1500         1500      March      2021
# 8810       1320         1329    January      2021
# 8811       1500         1602    January      2021
#
# [8727 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# Event              0
# Site               0
# Date               0
# UTCTime            0
# White              0
# Black              0
# WhiteElo           0
# BlackElo           0
# Result             0
# Tournament         0
# chess_clock        0
# time_day           0
# result_player      0
# result_opponent    0
# player_elo         0
# opponent_elo       0
# month_game         0
# year_game          0
# dtype: int64

# %%
df.describe()
# Out:
#        Tournament chess_clock   time_day result_player result_opponent  \
# count        8727        8727       8727          8727            8727
# unique          2           5          4             3               3
# top             0       Blitz  afternoon             1               0
# freq         7736        6503       3460          4359            4359
#
#        player_elo opponent_elo month_game year_game
# count        8727         8727       8727      8727
# unique        952         1141         12         4
# top          1500         1500   February      2023
# freq          204          247        986      3512

# %%
df = df[["Tournament", "chess_clock", "time_day", "result_player", "result_opponent", "player_elo", "opponent_elo", "month_game", "year_game"]]

# %%
df
# Out:
#      Tournament chess_clock   time_day result_player result_opponent  \
# 0             0       Blitz  afternoon             1               0
# 1             0       Blitz  afternoon             0               1
# 2             0       Blitz  afternoon             1               0
# 3             0       Blitz  afternoon             1               0
# 4             0       Blitz  afternoon             1               0
# ...         ...         ...        ...           ...             ...
# 8765          0       Rapid    morning             1               0
# 8767          1       other    evening             1               0
# 8768          1       other    evening             0               1
# 8810          0       Rapid  afternoon             0               1
# 8811          0       Rapid  afternoon             0               1
#
#      player_elo opponent_elo month_game year_game
# 0          1806         1787      March      2024
# 1          1811         1831      March      2024
# 2          1807         1708      March      2024
# 3          1802         1759      March      2024
# 4          1796         1792      March      2024
# ...         ...          ...        ...       ...
# 8765       1177         1155      March      2021
# 8767       1500         1500      March      2021
# 8768       1500         1500      March      2021
# 8810       1320         1329    January      2021
# 8811       1500         1602    January      2021
#
# [8727 rows x 9 columns]
